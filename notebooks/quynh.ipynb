# %%
pip install google-cloud-bigquery pandas pyarrow db-dtypes notebook ipykernel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud-bigquery in c:\users\asus\appdata\roaming\python\python311\site-packages (3.40.1)
# Requirement already satisfied: pandas in c:\users\asus\appdata\roaming\python\python311\site-packages (2.3.3)
# Requirement already satisfied: pyarrow in c:\users\asus\appdata\roaming\python\python311\site-packages (18.1.0)
# Requirement already satisfied: db-dtypes in c:\users\asus\appdata\roaming\python\python311\site-packages (1.5.0)
# Requirement already satisfied: notebook in c:\users\asus\appdata\roaming\python\python311\site-packages (7.4.7)
# Requirement already satisfied: ipykernel in c:\users\asus\appdata\roaming\python\python311\site-packages (6.30.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.28.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.43.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.32.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.7.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\asus\appdata\roaming\python\python311\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.9 in c:\users\asus\appdata\roaming\python\python311\site-packages (from notebook) (4.4.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from notebook) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (80.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.25.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (9.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\asus\appdata\roaming\python\python311\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\asus\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\asus\appdata\roaming\python\python311\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.2,>=1.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\asus\appdata\roaming\python\python311\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\asus\appdata\roaming\python\python311\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google.cloud import bigquery
import pandas as pd

# %%
client = bigquery.Client(project="bi-project-2026")
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\auth\_default.py:108: UserWarning:
#
# Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.

# %%
query = """
SELECT *
FROM `bi-project-2026.analytics.dim_customers`
LIMIT 100
"""
dim_customers = client.query(query).to_dataframe()
dim_customers
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#                              customer_sk customer_id       customer_name  \
# 0   44ec9f4e-0034-4ae7-9768-0e20e756398c      789421          Lotus Mart
# 1   8894ef37-1f10-4f5d-9353-355a599418cf      789221        Atlas Stores
# 2   c6b7a4ea-b3ec-432f-8f42-9200f48ab04d      789702        Sorefoz Mart
# 3   1d4607da-f3d7-4e31-8e1f-f5a39f3516c5      789902          Elite Mart
# 4   b984357d-6151-46ac-b717-ec86d6ab9087      789121            Coolblue
# 5   3feb8914-b27c-46f5-a0b0-4c174ce3bbf7      789521    Acclaimed Stores
# 6   d4eff9ca-b8f7-444c-964a-5aaa2aec05ed      789621         Expert Mart
# 7   29671ac7-ef49-4b23-92e4-c1bca14ff146      789321      Chiptec Stores
# 8   9270652c-17ab-4c8e-9692-ff483a813548      789102        Vijay Stores
# 0            0.76           0.65         0.49
# 1            0.92           0.65         0.60
# 2            0.78           0.66         0.51
# 3            0.89           0.66         0.59
# 4            0.92           0.67         0.62
# 5            0.92           0.67         0.62
# 6            0.75           0.68         0.51
# 7            0.89           0.75         0.67
# 8            0.92           0.75         0.69
# 9            0.91           0.76         0.69
# 10           0.92           0.76         0.70
# 11           0.78           0.77         0.60
# 12           0.86           0.77         0.66
# 13           0.85           0.78         0.66
# 14           0.88           0.78         0.69
# 15           0.89           0.78         0.69
# 16           0.75           0.79         0.59
# 17           0.76           0.79         0.60
# 18           0.78           0.79         0.62
# 19           0.85           0.79         0.67
# 20           0.86           0.79         0.68
# 21           0.90           0.79         0.71
# 22           0.85           0.80         0.68
# 23           0.86           0.80         0.69
# 24           0.89           0.80         0.71
# 25           0.92           0.80         0.74
# 26           0.79           0.81         0.64
# 27           0.85           0.81         0.69
# 28           0.87           0.81         0.70
# 29           0.87           0.81         0.70
# 30           0.90           0.81         0.73
# 31           0.90           0.81         0.73
# 32           0.91           0.81         0.74
# 33           0.92           0.81         0.75
# 34           0.86           0.82         0.71
#
#                                       run_id                        load_time  \
# 0   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 1   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 2   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 3   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 4   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 5   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 6   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 7   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 8   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 9   manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 10  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 11  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 12  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 13  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 14  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 15  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 16  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 17  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 18  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 19  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 20  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 21  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 22  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 23  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 24  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 25  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 26  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 27  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 28  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 29  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 30  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 31  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 32  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 33  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
# 34  manual__2026-03-24T16:07:06.924582+00:00 2026-03-24 16:08:15.842777+00:00
#
#     is_current
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# 30        True
# 31        True
# 32        True
# 33        True
# 34        True

# %%
query = """
SELECT *
FROM `bi-project-2026.analytics.fact_order_lines`
LIMIT 100
"""
fact_order_lines = client.query(query).to_dataframe()
fact_order_lines
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#                                  fact_sk order_line_id      order_id  \
# 0   f7926538-0746-4a15-8180-c297929455d2      OL011770  FAP410403201
# 1   f403d01f-1423-4806-86ee-2c7d3d1fad7c      OL012323  FAP410403203
# 2   65cf0493-7886-4fdf-aa7b-8ced37df41b8      OL012155  FAP410403303
# 3   eae1c7f4-413f-4644-956f-65dffdeb5df1      OL012225  FAP410403601
# 4   b2885830-d901-4d98-83d6-53e5eabaa0de      OL012113  FAP410403603
# ..                                   ...           ...           ...
# 95  397a0952-db40-44da-a576-1c7e727c74ce      OL014721  FAP419403603
# 96  0ff4d8de-a23a-4c10-89b0-6b04cf6d4520      OL014939  FAP420403402
# 97  61af6a71-bd1f-4197-9190-b63157fbc26b      OL014974  FAP420403501
# 98  4de7897e-e1da-4dfd-9f1c-8185b26d12a4      OL015633  FAP420403602
# 99  bebcaada-c2a8-427e-8840-51924be3d410      OL015436  FAP420403602
#
#    customer_id product_id                              order_sk  \
# 0       789403   25891201  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 1       789403   25891203  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 2       789403   25891303  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 3       789403   25891601  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 4       789403   25891603  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# ..         ...        ...                                   ...
# 95      789403   25891603  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 96      789403   25891402  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 97      789403   25891501  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 98      789403   25891602  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 99      789403   25891302  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
#
#                              customer_sk  \
# 0   06f41126-c932-44cc-95da-967bffe993cd
# 1   06f41126-c932-44cc-95da-967bffe993cd
# 2   06f41126-c932-44cc-95da-967bffe993cd
# 3   06f41126-c932-44cc-95da-967bffe993cd
# 4   06f41126-c932-44cc-95da-967bffe993cd
# ..                                   ...
# 95  06f41126-c932-44cc-95da-967bffe993cd
# 96  06f41126-c932-44cc-95da-967bffe993cd
# 97  06f41126-c932-44cc-95da-967bffe993cd
# 98  06f41126-c932-44cc-95da-967bffe993cd
# 99  06f41126-c932-44cc-95da-967bffe993cd
#
#                               product_sk order_placement_date  order_qty  ...  \
# 0   7e54bc16-2610-41f2-b05c-da1720d9b075           2022-04-07        408  ...
# 1   3e4313fb-bec8-4126-9329-98cc1d44a222           2022-04-09        158  ...
# 2   48cefadb-cf96-49cf-bd00-15ec5d7c5837           2022-04-08         82  ...
# 3   c76e599e-a744-416c-98fc-eeea7d35c223           2022-04-08        183  ...
# 4   0c8015f3-a660-4867-bf19-add0a4e400c8           2022-04-08        148  ...
# ..                                   ...                  ...        ...  ...
# 95  0c8015f3-a660-4867-bf19-add0a4e400c8           2022-04-16        179  ...
# 96  f50f117a-87a9-45cc-862a-366ba3eba953           2022-04-17        462  ...
# 97  4e4f8948-ffce-44c3-a8c3-cb322bd5da16           2022-04-17        175  ...
# 98  27f0067c-4ede-43b6-a609-f348c1cf93b4           2022-04-19        118  ...
# 99  10a9f977-eba1-410e-8e7b-f55eebea9c5f           2022-04-19         85  ...
#
#     agreed_delivery_date actual_delivery_date on_time  in_full  otif  \
# 0             2022-04-10           2022-04-10       1        0     0
# 1             2022-04-10           2022-04-10       1        1     1
# 2             2022-04-10           2022-04-11       0        0     0
# 3             2022-04-10           2022-04-09       1        0     0
# 4             2022-04-10           2022-04-10       1        1     1
# ..                   ...                  ...     ...      ...   ...
# 95            2022-04-19           2022-04-19       1        1     1
# 96            2022-04-20           2022-04-23       0        1     0
# 97            2022-04-20           2022-04-20       1        1     1
# 98            2022-04-20           2022-04-20       1        1     1
# 99            2022-04-20           2022-04-20       1        1     1
#
#     actual_revenue  expected_revenue     expense  \
# 0       42680000.0        44880000.0  36860000.0
# 1       10428000.0        10428000.0   9006000.0
# 2        8580000.0         9020000.0   6942000.0
# 3        2482000.0         3111000.0   1606000.0
# 4        4588000.0         4588000.0   2812000.0
# ..             ...               ...         ...
# 95       5549000.0         5549000.0   3401000.0
# 96      24024000.0        24024000.0  18018000.0
# 97      15225000.0        15225000.0  12950000.0
# 98       2596000.0         2596000.0   2124000.0
# 99      11645000.0        11645000.0   9435000.0
#
#                           load_time                                    run_id
# 0  2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 1  2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 2  2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 3  2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 4  2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# ..                              ...                                       ...
# 95 2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 96 2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 97 2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 98 2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
# 99 2026-03-24 16:20:02.879512+00:00  manual__2026-03-24T16:18:57.462115+00:00
#
# [100 rows x 21 columns]

# %%
query = """
SELECT *
FROM `bi-project-2026.analytics.fact_orders_aggregate`
LIMIT 100
"""
fact_orders_aggregate = client.query(query).to_dataframe()
fact_orders_aggregate
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#          order_id customer_id                           customer_sk  \
# 0    FAP416403403      789403  06f41126-c932-44cc-95da-967bffe993cd
# 1    FAP429403402      789403  06f41126-c932-44cc-95da-967bffe993cd
# 2    FAP430403402      789403  06f41126-c932-44cc-95da-967bffe993cd
# 3   FAUG824403503      789403  06f41126-c932-44cc-95da-967bffe993cd
# 4    FAUG85403603      789403  06f41126-c932-44cc-95da-967bffe993cd
# ..            ...         ...                                   ...
# 95   FAP423621601      789621  d4eff9ca-b8f7-444c-964a-5aaa2aec05ed
# 96   FAP427621601      789621  d4eff9ca-b8f7-444c-964a-5aaa2aec05ed
# 97   FAUG82621601      789621  d4eff9ca-b8f7-444c-964a-5aaa2aec05ed
# 98  FAUG816521602      789521  3feb8914-b27c-46f5-a0b0-4c174ce3bbf7
# 99   FJUL75521102      789521  3feb8914-b27c-46f5-a0b0-4c174ce3bbf7
#
#    order_placement_date  on_time  in_full  otif  \
# 0            2022-04-15        1        0     0
# 1            2022-04-27        1        0     0
# 2            2022-04-27        1        0     0
# 3            2022-08-22        1        0     0
# 4            2022-08-04        1        0     0
# ..                  ...      ...      ...   ...
# 95           2022-04-20        1        0     0
# 96           2022-04-25        1        0     0
# 97           2022-07-30        1        0     0
# 98           2022-08-13        0        0     0
# 99           2022-07-03        0        0     0
#
#                                       run_id
# 0   manual__2026-03-24T16:18:57.462115+00:00
# 1   manual__2026-03-24T16:18:57.462115+00:00
# 2   manual__2026-03-24T16:18:57.462115+00:00
# 3   manual__2026-03-24T16:18:57.462115+00:00
# 4   manual__2026-03-24T16:18:57.462115+00:00
# ..                                       ...
# 95  manual__2026-03-24T16:18:57.462115+00:00
# 96  manual__2026-03-24T16:18:57.462115+00:00
# 97  manual__2026-03-24T16:18:57.462115+00:00
# 98  manual__2026-03-24T16:18:57.462115+00:00
# 99  manual__2026-03-24T16:18:57.462115+00:00
#
# [100 rows x 8 columns]

# %%
query = """
SELECT
    p.category,
    p.product_name,
    p.product_id,
    COUNT(f.order_id) AS total_orders,
    ROUND(AVG(f.delivered_qty / f.order_qty) * 100, 2) AS fill_rate,
    ROUND(COUNTIF(f.actual_delivery_date > f.agreed_delivery_date) 
          / COUNT(f.order_id) * 100, 2) AS late_pct,
    ROUND(AVG(DATE_DIFF(f.actual_delivery_date, 
              f.agreed_delivery_date, DAY)), 2) AS avg_delay_days
FROM analytics.fact_order_lines f
JOIN analytics.dim_products p ON f.product_sk = p.product_sk
GROUP BY p.category, p.product_name, p.product_id
ORDER BY fill_rate
"""
product_perf_df = client.query(query).to_dataframe()
product_perf_df
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#      category     product_name product_id  total_orders  fill_rate  late_pct  \
# 0       Dairy    AM Butter 250   25891202          3125      96.32     28.67
# 1       Dairy    AM Butter 500   25891203          3272      96.46     29.61
# 2        Food  AM Biscuits 500   25891502          3195      96.49     27.98
# 3       Dairy      AM Ghee 250   25891301          3200      96.50     30.41
# 4       Dairy      AM Ghee 100   25891303          3098      96.52     29.95
# 5       Dairy      AM Milk 100   25891103          3184      96.53     28.17
# 6   Beverages       AM Tea 500   25891601          3184      96.54     28.55
# 7        Food  AM Biscuits 250   25891503          3186      96.58     28.28
# 8       Dairy      AM Milk 250   25891102          3197      96.58     29.21
# 9   Beverages       AM Tea 250   25891602          3143      96.58     28.89
# 10  Beverages       AM Tea 100   25891603          3134      96.61     28.37
# 11      Dairy       AM Curd 50   25891403          3187      96.62     28.62
# 12      Dairy      AM Curd 100   25891402          3177      96.62     28.71
# 13      Dairy    AM Butter 100   25891201          3170      96.66     29.18
# 14      Dairy      AM Ghee 150   25891302          3209      96.68     30.13
# 15      Dairy      AM Milk 500   25891101          3139      96.71     28.67
# 16      Dairy      AM Curd 250   25891401          3138      96.73     28.94
# 17       Food  AM Biscuits 750   25891501          3158      96.86     27.52
#
#     avg_delay_days
# 0             0.43
# 1             0.44
# 2             0.42
# 3             0.44
# 4             0.45
# 5             0.41
# 6             0.42
# 7             0.42
# 8             0.44
# 9             0.42
# 10            0.41
# 11            0.42
# 12            0.43
# 13            0.43
# 14            0.44
# 15            0.42
# 16            0.41
# 17            0.40

# %%
query = """
SELECT f.product_id, d.customer_id, d.city, p.product_name, p.category,
    ROUND(AVG(f.delivered_qty / f.order_qty) * 100, 2) AS fill_rate,
    ROUND(COUNTIF(f.actual_delivery_date > f.agreed_delivery_date) / COUNT(f.order_id) * 100, 2) AS late_pct
FROM analytics.fact_order_lines f
JOIN analytics.dim_customers d ON d.customer_id = f.customer_id
JOIN analytics.dim_products p ON p.product_id = f.product_id
GROUP BY f.product_id, d.customer_id, d.city, p.product_name, p.category
"""
product_in_city_df = client.query(query).to_dataframe()
product_in_city_df
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#     product_id customer_id       city   product_name   category  fill_rate  \
# 0     25891201      789403   Vadodara  AM Butter 100      Dairy      98.21
# 1     25891203      789403   Vadodara  AM Butter 500      Dairy      98.21
# 2     25891303      789403   Vadodara    AM Ghee 100      Dairy      97.05
# 3     25891601      789403   Vadodara     AM Tea 500  Beverages      97.59
# 4     25891603      789403   Vadodara     AM Tea 100  Beverages      97.65
# ..         ...         ...        ...            ...        ...        ...
# 625   25891101      789721  Ahmedabad    AM Milk 500      Dairy      97.01
# 626   25891401      789721  Ahmedabad    AM Curd 250      Dairy      98.00
# 627   25891402      789721  Ahmedabad    AM Curd 100      Dairy      97.22
# 628   25891103      789721  Ahmedabad    AM Milk 100      Dairy      97.45
# 629   25891303      789721  Ahmedabad    AM Ghee 100      Dairy      96.99
#
#      late_pct
# 0       16.85
# 1       15.79
# 2       11.83
# 3        9.28
# 4       15.29
# ..        ...
# 625     13.79
# 626     16.67
# 627     19.32
# 628     13.00
# 629     18.07
#
# [630 rows x 7 columns]

# %%
fill_rate_df = (
    product_in_city_df
    .groupby(['city', 'category'], as_index=False)
    .agg({'fill_rate': 'mean'})
)

fill_rate_df
# Out:
#         city   category  fill_rate
# 0  Ahmedabad  Beverages  96.748056
# 1  Ahmedabad      Dairy  96.774028
# 2  Ahmedabad       Food  96.788333
# 3      Surat  Beverages  96.752121
# 4      Surat      Dairy  96.603030
# 5      Surat       Food  96.683030
# 6   Vadodara  Beverages  96.294444
# 7   Vadodara      Dairy  96.354444
# 8   Vadodara       Food  96.414722

# %%
import plotly.express as px

fig = px.bar(
    fill_rate_df,
    x='category',
    y='fill_rate',
    color='city',
    barmode='group',
    text='fill_rate',
    title='Average Fill Rate by Category and City'
)

fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')

fig.update_layout(
    xaxis_title='Category',
    yaxis_title='Average Fill Rate (%)',
    legend_title='City'
)

fig.show()

# %%
late_pct_df = (
    product_in_city_df
    .groupby(['city', 'category'], as_index=False)
    .agg({'late_pct': 'mean'})
)

late_pct_df
# Out:
#         city   category   late_pct
# 0  Ahmedabad  Beverages  30.408333
# 1  Ahmedabad      Dairy  30.135694
# 2  Ahmedabad       Food  29.389444
# 3      Surat  Beverages  25.783939
# 4      Surat      Dairy  26.906439
# 5      Surat       Food  24.803030
# 6   Vadodara  Beverages  29.845000
# 7   Vadodara      Dairy  30.291597
# 8   Vadodara       Food  29.853611

# %%
fig = px.bar(
    late_pct_df,
    x='category',
    y='late_pct',
    color='city',
    barmode='group',
    text='late_pct',
    title='Average Late Percentage by Category and City'
)

fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')

fig.update_layout(
    xaxis_title='Category',
    yaxis_title='Average Late Percentage (%)',
    legend_title='City'
)

fig.show()

# %%
query = """
SELECT 
    f.product_id,
    d.city,
    p.product_name,
    p.category,
    ROUND(AVG(SAFE_DIVIDE(f.delivered_qty, f.order_qty)) * 100, 2) AS fill_rate,
    ROUND(COUNTIF(f.actual_delivery_date > f.agreed_delivery_date) / COUNT(f.order_id) * 100, 2) AS late_pct,
    COUNT(DISTINCT f.order_id) AS total_orders
FROM analytics.fact_order_lines f
JOIN analytics.dim_customers d 
    ON d.customer_id = f.customer_id
JOIN analytics.dim_products p 
    ON p.product_id = f.product_id
GROUP BY 
    f.product_id, d.city, p.product_name, p.category
"""
product_in_city_df = client.query(query).to_dataframe()
product_in_city_df
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#    product_id       city     product_name   category  fill_rate  late_pct  \
# 0    25891201   Vadodara    AM Butter 100      Dairy      96.41     30.54
# 1    25891203   Vadodara    AM Butter 500      Dairy      96.06     30.36
# 2    25891303   Vadodara      AM Ghee 100      Dairy      96.39     30.49
# 3    25891601   Vadodara       AM Tea 500  Beverages      96.14     30.76
# 4    25891603   Vadodara       AM Tea 100  Beverages      96.38     29.52
# 5    25891403   Vadodara       AM Curd 50      Dairy      96.21     28.68
# 6    25891101   Vadodara      AM Milk 500      Dairy      96.50     30.16
# 7    25891301   Vadodara      AM Ghee 250      Dairy      96.23     32.25
# 8    25891401   Vadodara      AM Curd 250      Dairy      96.65     29.83
# 9    25891503   Vadodara  AM Biscuits 250       Food      96.48     28.35
# 10   25891102   Vadodara      AM Milk 250      Dairy      96.39     31.18
# 11   25891302   Vadodara      AM Ghee 150      Dairy      96.34     30.42
# 12   25891502   Vadodara  AM Biscuits 500       Food      96.25     29.13
# 13   25891103   Vadodara      AM Milk 100      Dairy      96.24     29.16
# 14   25891501   Vadodara  AM Biscuits 750       Food      96.42     30.02
# 15   25891602   Vadodara       AM Tea 250  Beverages      96.32     29.14
# 16   25891402   Vadodara      AM Curd 100      Dairy      96.38     29.98
# 17   25891202   Vadodara    AM Butter 250      Dairy      96.17     31.69
# 18   25891401  Ahmedabad      AM Curd 250      Dairy      96.92     29.24
# 19   25891303  Ahmedabad      AM Ghee 100      Dairy      96.67     29.75
# 20   25891301  Ahmedabad      AM Ghee 250      Dairy      96.73     31.51
# 21   25891403  Ahmedabad       AM Curd 50      Dairy      96.88     32.34
# 22   25891502  Ahmedabad  AM Biscuits 500       Food      96.77     28.81
# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# =========================
# 1. Prepare data
# =========================
prod = product_in_city_df.copy()

prod['label'] = prod['product_name'] + '\n(' + prod['category'] + ')'

# color by category
categories = prod['category'].unique()
palette = dict(zip(categories, ['#d62728', '#2ca02c','#1f77b4','#ff7f0e','#9467bd']))
prod['color'] = prod['category'].map(palette)

# size by total orders
prod['size'] = (prod['total_orders'] / prod['total_orders'].max() * 300).clip(lower=40)

# city order
city_list = ['Vadodara', 'Surat', 'Ahmedabad']

# global axis range for consistency
x_min = prod['late_pct'].min() - 1
x_max = prod['late_pct'].max() + 1
y_min = prod['fill_rate'].min() - 0.2
y_max = prod['fill_rate'].max() + 0.2

# =========================
# 2. Create subplots
# =========================
fig, axes = plt.subplots(3, 1, figsize=(10, 20), sharex=True, sharey=True)

for ax, city in zip(axes, city_list):
    city_df = prod[prod['city'] == city].copy()
    
    # median per city
    med_fill = city_df['fill_rate'].median()
    med_late = city_df['late_pct'].median()
    
    # worst products in each city
    worst_prod = city_df[
        (city_df['late_pct'] > med_late) &
        (city_df['fill_rate'] < med_fill)
    ]
    
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)

    # quadrant shading
    y_norm = (med_fill - y_min) / (y_max - y_min)

    ax.axvspan(x_min, med_late, ymin=0,      ymax=y_norm, alpha=0.06, color='orange')
    ax.axvspan(med_late, x_max, ymin=0,      ymax=y_norm, alpha=0.10, color='red')
    ax.axvspan(x_min, med_late, ymin=y_norm, ymax=1,      alpha=0.06, color='green')
    ax.axvspan(med_late, x_max, ymin=y_norm, ymax=1,      alpha=0.04, color='orange')

    # scatter
    ax.scatter(
        city_df['late_pct'],
        city_df['fill_rate'],
        c=city_df['color'],
        s=city_df['size'],
        alpha=0.85,
        edgecolor='black',
        linewidth=0.4,
        zorder=3
    )

    # median lines
    ax.axvline(x=med_late, color='gray', linewidth=0.8, linestyle='--')
    ax.axhline(y=med_fill, color='gray', linewidth=0.8, linestyle='--')

    # titles and labels
    ax.set_title(city, fontsize=12, weight='bold')
    ax.set_xlabel('% Orders Late')

axes[0].set_ylabel('Fill Rate %')

# =========================
# 3. Legend
# =========================
color_legend = [
    Line2D([0], [0], marker='o', color='w',
           markerfacecolor=palette[cat], markeredgecolor='black',
           markersize=9, label=cat)
    for cat in categories
]

fig.legend(
    handles=color_legend,
    loc='lower center',
    ncol=len(categories),
    fontsize=9,
    frameon=False,
    title='Category'
)

fig.suptitle('Product Performance by City — Late % vs Fill Rate', fontsize=15, weight='bold')
plt.tight_layout(rect=[0, 0.08, 1, 0.95])
plt.show()

# %%
import numpy as np

product_in_vadodara = product_in_city_df.loc[product_in_city_df['city'] == 'Vadodara', :].copy()

med_fill = product_in_vadodara['fill_rate'].median()
med_late = product_in_vadodara['late_pct'].median()

conditions = [
    (product_in_vadodara['fill_rate'] >= med_fill) & (product_in_vadodara['late_pct'] <= med_late),
    (product_in_vadodara['fill_rate'] >= med_fill) & (product_in_vadodara['late_pct'] > med_late),
    (product_in_vadodara['fill_rate'] < med_fill) & (product_in_vadodara['late_pct'] <= med_late),
    (product_in_vadodara['fill_rate'] < med_fill) & (product_in_vadodara['late_pct'] > med_late)
]

choices = [1, 2, 3, 4]

product_in_vadodara['group'] = np.select(conditions, choices, default=0)

product_in_vadodara.sort_values('group', ascending=True)
# Out:
#    product_id      city     product_name   category  fill_rate  late_pct  \
# 4    25891603  Vadodara       AM Tea 100  Beverages      96.38     29.52
# 14   25891501  Vadodara  AM Biscuits 750       Food      96.42     30.02
# 9    25891503  Vadodara  AM Biscuits 250       Food      96.48     28.35
# 8    25891401  Vadodara      AM Curd 250      Dairy      96.65     29.83
# 16   25891402  Vadodara      AM Curd 100      Dairy      96.38     29.98
# 10   25891102  Vadodara      AM Milk 250      Dairy      96.39     31.18
# 6    25891101  Vadodara      AM Milk 500      Dairy      96.50     30.16
# 0    25891201  Vadodara    AM Butter 100      Dairy      96.41     30.54
# 2    25891303  Vadodara      AM Ghee 100      Dairy      96.39     30.49
# 13   25891103  Vadodara      AM Milk 100      Dairy      96.24     29.16
# 15   25891602  Vadodara       AM Tea 250  Beverages      96.32     29.14
# 12   25891502  Vadodara  AM Biscuits 500       Food      96.25     29.13
# 5    25891403  Vadodara       AM Curd 50      Dairy      96.21     28.68
# 7    25891301  Vadodara      AM Ghee 250      Dairy      96.23     32.25
# 1    25891203  Vadodara    AM Butter 500      Dairy      96.06     30.36
# 3    25891601  Vadodara       AM Tea 500  Beverages      96.14     30.76
# 11   25891302  Vadodara      AM Ghee 150      Dairy      96.34     30.42
# 17   25891202  Vadodara    AM Butter 250      Dairy      96.17     31.69
#
#     total_orders  group
# 4           1094      1
# 14          1066      1
# 9           1090      1
# 8           1076      1
# 16          1074      1
# 10          1113      2
# 6           1081      2
# 0           1084      2
# 2           1030      2
# 13          1070      3
# 15          1064      3
# 12          1109      3
# 5           1102      3
# 7           1073      4
# 1           1156      4
# 3           1099      4
# 11          1121      4
# 17          1076      4

# %%
product_in_vadodara_count = (
    product_in_vadodara
    .groupby(['group'])
    .size()
    .reset_index(name='count')
)

product_in_vadodara_count
# Out:
#    group  count
# 0      1      5
# 1      2      4
# 2      3      4
# 3      4      5

# %%
product_in_vadodara_count = (
    product_in_vadodara
    .groupby(['group', 'category'])
    .size()
    .reset_index(name='count')
)

product_in_vadodara_count
# Out:
#    group   category  count
# 0      1  Beverages      1
# 1      1      Dairy      2
# 2      1       Food      2
# 3      2      Dairy      4
# 4      3  Beverages      1
# 5      3      Dairy      2
# 6      3       Food      1
# 7      4  Beverages      1
# 8      4      Dairy      4

# %%
worst_in_vadodara = product_in_vadodara.loc[product_in_vadodara['group'] == 4, ['product_name']].copy()
worst_in_vadodara
# Out:
#      product_name
# 1   AM Butter 500
# 3      AM Tea 500
# 7     AM Ghee 250
# 11    AM Ghee 150
# 17  AM Butter 250

# %%
product_in_surat = product_in_city_df.loc[product_in_city_df['city'] == 'Surat', :].copy()

med_fill = product_in_surat['fill_rate'].median()
med_late = product_in_surat['late_pct'].median()

conditions = [
    (product_in_surat['fill_rate'] >= med_fill) & (product_in_surat['late_pct'] <= med_late),
    (product_in_surat['fill_rate'] >= med_fill) & (product_in_surat['late_pct'] > med_late),
    (product_in_surat['fill_rate'] < med_fill) & (product_in_surat['late_pct'] <= med_late),
    (product_in_surat['fill_rate'] < med_fill) & (product_in_surat['late_pct'] > med_late)
]

choices = [1, 2, 3, 4]

product_in_surat['group'] = np.select(conditions, choices, default=0)

product_in_surat.sort_values('group', ascending=True)
# Out:
#    product_id   city     product_name   category  fill_rate  late_pct  \
# 37   25891103  Surat      AM Milk 100      Dairy      96.66     26.22
# 41   25891101  Surat      AM Milk 500      Dairy      97.00     26.28
# 43   25891501  Surat  AM Biscuits 750       Food      97.14     22.87
# 45   25891603  Surat       AM Tea 100  Beverages      96.73     24.87
# 49   25891403  Surat       AM Curd 50      Dairy      96.78     24.60
# 48   25891102  Surat      AM Milk 250      Dairy      96.78     27.25
# 46   25891401  Surat      AM Curd 250      Dairy      96.59     27.60
# 38   25891302  Surat      AM Ghee 150      Dairy      96.77     27.42
# 51   25891602  Surat       AM Tea 250  Beverages      96.84     27.27
# 44   25891502  Surat  AM Biscuits 500       Food      96.47     25.88
# 47   25891503  Surat  AM Biscuits 250       Food      96.57     25.77
# 40   25891201  Surat    AM Butter 100      Dairy      96.43     25.43
# 50   25891601  Surat       AM Tea 500  Beverages      96.58     24.51
# 42   25891303  Surat      AM Ghee 100      Dairy      96.47     29.62
# 36   25891203  Surat    AM Butter 500      Dairy      96.56     28.06
# 39   25891402  Surat      AM Curd 100      Dairy      96.43     26.57
# 52   25891202  Surat    AM Butter 250      Dairy      96.46     26.54
# 53   25891301  Surat      AM Ghee 250      Dairy      96.52     27.23
#
#     total_orders  group
# 37          1003      1
# 41           978      1
# 43           997      1
# 45           945      1
# 49          1012      1
# 48          1002      2
# 46           971      2
# 38          1014      2
# 51           990      2
# 44          1024      3
# 47          1001      3
# 40           983      3
# 50           975      3
# 42           969      4
# 36          1036      4
# 39           956      4
# 52           976      4
# 53          1010      4

# %%
product_in_surat_count = (
    product_in_surat
    .groupby('group')
    .size()
    .reset_index(name='count')
)

product_in_surat_count
# Out:
#    group  count
# 0      1      5
# 1      2      4
# 2      3      4
# 3      4      5

# %%
worst_in_surat = product_in_surat.loc[product_in_surat['group'] == 4, ['product_name']].copy()
worst_in_surat
# Out:
#      product_name
# 36  AM Butter 500
# 39    AM Curd 100
# 42    AM Ghee 100
# 52  AM Butter 250
# 53    AM Ghee 250

# %%
import numpy as np

product_in_ahmedabad = product_in_city_df.loc[product_in_city_df['city'] == 'Ahmedabad', :].copy()

med_fill = product_in_ahmedabad['fill_rate'].median()
med_late = product_in_ahmedabad['late_pct'].median()

conditions = [
    (product_in_ahmedabad['fill_rate'] >= med_fill) & (product_in_ahmedabad['late_pct'] <= med_late),
    (product_in_ahmedabad['fill_rate'] >= med_fill) & (product_in_ahmedabad['late_pct'] > med_late),
    (product_in_ahmedabad['fill_rate'] < med_fill) & (product_in_ahmedabad['late_pct'] <= med_late),
    (product_in_ahmedabad['fill_rate'] < med_fill) & (product_in_ahmedabad['late_pct'] > med_late)
]

choices = [1, 2, 3, 4]

product_in_ahmedabad['group'] = np.select(conditions, choices, default=0)

product_in_ahmedabad.sort_values('group', ascending=True)
# Out:
#    product_id       city     product_name   category  fill_rate  late_pct  \
# 18   25891401  Ahmedabad      AM Curd 250      Dairy      96.92     29.24
# 22   25891502  Ahmedabad  AM Biscuits 500       Food      96.77     28.81
# 24   25891501  Ahmedabad  AM Biscuits 750       Food      97.03     29.32
# 26   25891402  Ahmedabad      AM Curd 100      Dairy      97.01     29.29
# 30   25891302  Ahmedabad      AM Ghee 150      Dairy      96.97     32.40
# 31   25891203  Ahmedabad    AM Butter 500      Dairy      96.81     30.31
# 32   25891601  Ahmedabad       AM Tea 500  Beverages      96.91     29.91
# 21   25891403  Ahmedabad       AM Curd 50      Dairy      96.88     32.34
# 33   25891201  Ahmedabad    AM Butter 100      Dairy      97.11     31.19
# 25   25891103  Ahmedabad      AM Milk 100      Dairy      96.70     28.98
# 19   25891303  Ahmedabad      AM Ghee 100      Dairy      96.67     29.75
# 23   25891202  Ahmedabad    AM Butter 250      Dairy      96.34     27.59
# 29   25891102  Ahmedabad      AM Milk 250      Dairy      96.57     29.02
# 34   25891101  Ahmedabad      AM Milk 500      Dairy      96.66     29.35
# 28   25891503  Ahmedabad  AM Biscuits 250       Food      96.69     30.50
# 20   25891301  Ahmedabad      AM Ghee 250      Dairy      96.73     31.51
# 27   25891603  Ahmedabad       AM Tea 100  Beverages      96.73     30.23
# 35   25891602  Ahmedabad       AM Tea 250  Beverages      96.61     30.12
#
#     total_orders  group
# 18          1091      1
# 22          1062      1
# 24          1095      1
# 26          1147      1
# 30          1074      2
# 31          1079      2
# 32          1110      2
# 21          1073      2
# 33          1103      2
# 25          1111      3
# 19          1099      3
# 23          1073      3
# 29          1082      3
# 34          1080      3
# 28          1095      4
# 20          1117      4
# 27          1095      4
# 35          1089      4

# %%
product_in_ahmedabad_count = (
    product_in_ahmedabad
    .groupby('group')
    .size()
    .reset_index(name='count')
)

product_in_ahmedabad_count
# Out:
#    group  count
# 0      1      4
# 1      2      5
# 2      3      5
# 3      4      4

# %%
worst_in_ahmedabad = product_in_ahmedabad.loc[product_in_ahmedabad['group'] == 4, ['product_name']].copy()
worst_in_ahmedabad
# Out:
#        product_name
# 20      AM Ghee 250
# 27       AM Tea 100
# 28  AM Biscuits 250
# 35       AM Tea 250

# %% [markdown]
# ## REGRESSION

# %%
dim_targets_orders
# Out:
#                                 order_sk customer_sk customer_id  \
# 0   c5365722-a13c-402c-bd60-346103a51aa9        None      789122
# 1   2400fef3-4c42-4682-a4e6-dcc3a1863772        None      789903
# 2   d2bdd4b4-e6f4-4da5-b60d-31c2f990bbff        None      789421
# 3   8cfbd30a-f392-48ec-b5fd-4aed4499f386        None      789702
# 4   73b81e32-daa0-4433-beec-4d8d048b1dea        None      789103
# 5   c5baf63c-f494-426a-a4c8-249862d6ca2d        None      789601
# 6   93b1321f-bdec-4492-a077-8933b75467f8        None      789520
# 7   f6601f83-be17-4e32-b113-2fa4919a44f4        None      789721
# 8   6632f68a-7b72-40a3-8977-95edbacf806a        None      789603
# 9   497e69ec-5eec-46af-ad4e-e6ccd99dd01e        None      789220
# 10  8caa7a11-01af-454d-8b8c-fc7a8ffce081        None      789203
# 11  f03567c6-d5c1-4f5f-a701-24aad45c66ac        None      789121
# 12  998247e4-5812-442c-ab4e-00b8349a300e        None      789720
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# 30        True
# 31        True
# 32        True
# 33        True
# 34        True

# %%
query = """
SELECT 
    c.city, 
    AVG(t.ontime_target) as avg_ontime_target,
    AVG(t.infull_target) as avg_infull_target,
FROM analytics.dim_customers c
JOIN analytics.dim_targets_orders t ON c.customer_id = t.customer_id
GROUP BY c.city
    
"""
target_in_city_df = client.query(query).to_dataframe()
target_in_city_df
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#         city  avg_ontime_target  avg_infull_target
# 0  Ahmedabad           0.858333           0.773333
# 1      Surat           0.862727           0.769091
# 2   Vadodara           0.861667           0.753333

# %%
fact_order_lines.sort_values('order_id')
# Out:
#                                  fact_sk order_line_id      order_id  \
# 0   f7926538-0746-4a15-8180-c297929455d2      OL011770  FAP410403201
# 1   f403d01f-1423-4806-86ee-2c7d3d1fad7c      OL012323  FAP410403203
# 2   65cf0493-7886-4fdf-aa7b-8ced37df41b8      OL012155  FAP410403303
# 3   eae1c7f4-413f-4644-956f-65dffdeb5df1      OL012225  FAP410403601
# 4   b2885830-d901-4d98-83d6-53e5eabaa0de      OL012113  FAP410403603
# ..                                   ...           ...           ...
# 95  397a0952-db40-44da-a576-1c7e727c74ce      OL014721  FAP419403603
# 96  0ff4d8de-a23a-4c10-89b0-6b04cf6d4520      OL014939  FAP420403402
# 97  61af6a71-bd1f-4197-9190-b63157fbc26b      OL014974  FAP420403501
# 98  4de7897e-e1da-4dfd-9f1c-8185b26d12a4      OL015633  FAP420403602
# 99  bebcaada-c2a8-427e-8840-51924be3d410      OL015436  FAP420403602
#
#    customer_id product_id                              order_sk  \
# 0       789403   25891201  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 1       789403   25891203  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 2       789403   25891303  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 3       789403   25891601  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 4       789403   25891603  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# ..         ...        ...                                   ...
# 95      789403   25891603  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 96      789403   25891402  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 97      789403   25891501  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 98      789403   25891602  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
# 99      789403   25891302  0dc678c9-4b8b-4f2c-ac3b-72417180f3ba
#
#                              customer_sk  \
# 0   06f41126-c932-44cc-95da-967bffe993cd
# 1   06f41126-c932-44cc-95da-967bffe993cd
# 2   06f41126-c932-44cc-95da-967bffe993cd
# 3   06f41126-c932-44cc-95da-967bffe993cd
# 4   06f41126-c932-44cc-95da-967bffe993cd
# ..                                   ...
# 95  06f41126-c932-44cc-95da-967bffe993cd
# 96  06f41126-c932-44cc-95da-967bffe993cd
# 97  06f41126-c932-44cc-95da-967bffe993cd
# 98  06f41126-c932-44cc-95da-967bffe993cd
# 99  06f41126-c932-44cc-95da-967bffe993cd
#
#                               product_sk order_placement_date  order_qty  ...  \
# 0   7e54bc16-2610-41f2-b05c-da1720d9b075           2022-04-07        408  ...
# 1   3e4313fb-bec8-4126-9329-98cc1d44a222           2022-04-09        158  ...
# 2   48cefadb-cf96-49cf-bd00-15ec5d7c5837           2022-04-08         82  ...
# 3   c76e599e-a744-416c-98fc-eeea7d35c223           2022-04-08        183  ...
# 4   0c8015f3-a660-4867-bf19-add0a4e400c8           2022-04-08        148  ...
# ..                                   ...                  ...        ...  ...
# 95  0c8015f3-a660-4867-bf19-add0a4e400c8           2022-04-16        179  ...
# 16  0df67f4d-02f7-463e-8e21-86439c184031   25891502  AM Biscuits 500
# 17  4e4f8948-ffce-44c3-a8c3-cb322bd5da16   25891501  AM Biscuits 750
#
#      category     price      cost                                    run_id  \
# 0   Beverages   17000.0   11000.0  manual__2026-03-24T16:07:06.924582+00:00
# 1   Beverages   22000.0   18000.0  manual__2026-03-24T16:07:06.924582+00:00
# 2   Beverages   31000.0   19000.0  manual__2026-03-24T16:07:06.924582+00:00
# 3       Dairy   52000.0   39000.0  manual__2026-03-24T16:07:06.924582+00:00
# 4       Dairy   56000.0   40000.0  manual__2026-03-24T16:07:06.924582+00:00
# 5       Dairy   66000.0   51000.0  manual__2026-03-24T16:07:06.924582+00:00
# 6       Dairy   66000.0   57000.0  manual__2026-03-24T16:07:06.924582+00:00
# 7       Dairy   87000.0   71000.0  manual__2026-03-24T16:07:06.924582+00:00
# 8       Dairy  110000.0   95000.0  manual__2026-03-24T16:07:06.924582+00:00
# 9       Dairy  110000.0   89000.0  manual__2026-03-24T16:07:06.924582+00:00
# 10      Dairy  121000.0   94000.0  manual__2026-03-24T16:07:06.924582+00:00
# 11      Dairy  123000.0  100000.0  manual__2026-03-24T16:07:06.924582+00:00
# 12      Dairy  137000.0  111000.0  manual__2026-03-24T16:07:06.924582+00:00
# 13      Dairy  145000.0  108000.0  manual__2026-03-24T16:07:06.924582+00:00
# 14      Dairy  147000.0  118000.0  manual__2026-03-24T16:07:06.924582+00:00
# 15       Food   35000.0   28000.0  manual__2026-03-24T16:07:06.924582+00:00
# 16       Food   37000.0   32000.0  manual__2026-03-24T16:07:06.924582+00:00
# 17       Food   87000.0   74000.0  manual__2026-03-24T16:07:06.924582+00:00
#
#                           load_time  is_current
# 0  2026-03-24 16:08:06.449213+00:00        True
# 1  2026-03-24 16:08:06.449213+00:00        True
# 2  2026-03-24 16:08:06.449213+00:00        True
# 3  2026-03-24 16:08:06.449213+00:00        True
# 4  2026-03-24 16:08:06.449213+00:00        True
# 5  2026-03-24 16:08:06.449213+00:00        True
# 6  2026-03-24 16:08:06.449213+00:00        True
# 7  2026-03-24 16:08:06.449213+00:00        True
# 8  2026-03-24 16:08:06.449213+00:00        True
# 9  2026-03-24 16:08:06.449213+00:00        True
# 10 2026-03-24 16:08:06.449213+00:00        True
# 11 2026-03-24 16:08:06.449213+00:00        True
# 12 2026-03-24 16:08:06.449213+00:00        True
# 13 2026-03-24 16:08:06.449213+00:00        True
# 14 2026-03-24 16:08:06.449213+00:00        True
# 15 2026-03-24 16:08:06.449213+00:00        True
# 16 2026-03-24 16:08:06.449213+00:00        True
# 17 2026-03-24 16:08:06.449213+00:00        True

# %%
query = """
SELECT 
    c.city,
    o.product_id,
    p.product_name,
    p.category,
    CAST(SUM(o.actual_revenue) AS NUMERIC) as actual_revenue,
    CAST(SUM(o.expected_revenue) AS NUMERIC) as expected_revenue,
    ROUND(CAST(SUM(GREATEST(o.expected_revenue - o.actual_revenue, 0)) AS NUMERIC), 0) AS lost_revenue,
    ROUND(AVG(SAFE_DIVIDE(o.delivered_qty, o.order_qty)) * 100, 2) AS avg_fill_rate,
# 30  58271005000.000000000  1887175000.000000000          96.78         27.25
# 31  52673040000.000000000  1729602000.000000000          96.78         24.60
# 32   2087243000.000000000    72641000.000000000          96.58         24.51
# 33   2728638000.000000000    88902000.000000000          96.84         27.27
# 34  19086408000.000000000   672804000.000000000          96.46         26.54
# 35   3400320000.000000000   117712000.000000000          96.52         27.23
# 36   9255583000.000000000   323320000.000000000          96.34         30.42
# 37  19604624000.000000000   694148000.000000000          96.38         29.98
# 38  57089949000.000000000  2119593000.000000000          96.21         28.68
# 39  16297797000.000000000   588120000.000000000          96.42         30.02
# 40  22821084000.000000000   910536000.000000000          96.06         30.36
# 41   7232723000.000000000   267251000.000000000          96.25         29.13
# 42   6758850000.000000000   234045000.000000000          96.48         28.35
# 43  52847442000.000000000  1985958000.000000000          96.24         29.16
# 44   2967470000.000000000   109758000.000000000          96.32         29.14
# 45   4305745000.000000000   156116000.000000000          96.38         29.52
# 46  21541080000.000000000   813186000.000000000          96.17         31.69
# 47  64416830000.000000000  2256925000.000000000          96.39         31.18
# 48   2305489000.000000000    88502000.000000000          96.14         30.76
# 49  37765482000.000000000  1312482000.000000000          96.50         30.16
# 50   6717480000.000000000   242220000.000000000          96.39         30.49
# 51   3540152000.000000000   132832000.000000000          96.23         32.25
# 52  45522862000.000000000  1528714000.000000000          96.65         29.83
# 53  35778710000.000000000  1312190000.000000000          96.41         30.54

# %%
# 1. Gom nhóm theo City và Category
# Chúng ta dùng mean cho các tỉ lệ % và sum cho doanh thu mất đi
summary_df = perf_in_city_df.groupby(['city', 'category']).agg({
    'avg_fill_rate': 'mean',
    'avg_late_pct': 'mean',
    'lost_revenue': 'sum'
}).reset_index()

summary_df = summary_df.sort_values(by='city', ascending=False)

summary_df['avg_fill_rate'] = summary_df['avg_fill_rate'].round(2)
summary_df['avg_late_pct'] = summary_df['avg_late_pct'].round(2)

final_report = summary_df[['city', 'category', 'avg_fill_rate', 'avg_late_pct', 'lost_revenue']]

print(final_report)
# Out:
#         city   category  avg_fill_rate  avg_late_pct           lost_revenue
# 6   Vadodara  Beverages          96.28         29.81    354376000.000000000
# 7   Vadodara      Dairy          96.33         30.40  13632104000.000000000
# 8   Vadodara       Food          96.38         29.17   1089416000.000000000
# 3      Surat  Beverages          96.72         25.55    283497000.000000000
# 4      Surat      Dairy          96.62         26.90  11427183000.000000000
# 5      Surat       Food          96.73         24.84    895062000.000000000
# 0  Ahmedabad  Beverages          96.75         30.09    314643000.000000000
# 1  Ahmedabad      Dairy          96.78         30.08  12153771000.000000000
# 2  Ahmedabad       Food          96.83         29.54    939795000.000000000

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np


# 1. Tạo bản sao để tránh ảnh hưởng df gốc
df_model = perf_in_city_df.copy()
df_model['lost_rev_pct'] = (df_model['lost_revenue'] / (df_model['expected_revenue'])) * 100

# 2. Ép kiểu 3 cột chính về float
cols_to_fix = ['lost_rev_pct', 'avg_fill_rate', 'avg_late_pct']
for col in cols_to_fix:
    df_model[col] = pd.to_numeric(df_model[col], errors='coerce')

# 3. Tạo biến giả (Dummies)
df_model = pd.get_dummies(df_model, columns=['category', 'city'], drop_first=True)

# 4. CHỐT CHẶN CUỐI: Ép toàn bộ dataframe về float64 để loại bỏ kiểu 'object'
df_model = df_model.select_dtypes(include=[np.number, 'bool']).astype(float)

# 5. Xác định X và y
# Lưu ý: Tên cột dummies có thể thay đổi tùy vào dữ liệu của bạn, 
# hãy kiểm tra df_model.columns để điền chính xác
X_cols = [col for col in df_model.columns if col != 'lost_rev_pct']
X = df_model[X_cols]
X = sm.add_constant(X)
y = df_model['lost_rev_pct']

# 6. Chạy mô hình
model = sm.OLS(y, X).fit()

# 7. Xem kết quả
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           lost_rev_pct   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     158.0
# Date:                Thu, 02 Apr 2026   Prob (F-statistic):           2.01e-29
# Time:                        17:03:06   Log-Likelihood:                 82.614
# No. Observations:                  54   AIC:                            -151.2
# Df Residuals:                      47   BIC:                            -137.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             91.1158      4.267     21.353      0.000      82.531      99.700
# avg_fill_rate     -0.9085      0.044    -20.645      0.000      -0.997      -0.820
# avg_late_pct       0.0025      0.007      0.376      0.708      -0.011       0.016
# category_Dairy    -0.0457      0.021     -2.139      0.038      -0.089      -0.003
# category_Food     -0.0364      0.027     -1.352      0.183      -0.091       0.018
# city_Surat         0.0254      0.031      0.813      0.420      -0.037       0.088
# city_Vadodara      0.0017      0.027      0.061      0.952      -0.053       0.057
# ==============================================================================
# Omnibus:                        5.432   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                6.701
# Skew:                          -0.218   Prob(JB):                       0.0351
# Kurtosis:                       4.670   Cond. No.                     5.63e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
avg_overall = perf_in_city_df[['avg_fill_rate', 'avg_late_pct']].mean()

print("--- Trung bình đơn giản toàn doanh nghiệp ---")
print(f"Fill Rate trung bình: {avg_overall['avg_fill_rate']:.2f}%")
print(f"Tỷ lệ giao trễ trung bình: {avg_overall['avg_late_pct']:.2f}%")
# Out:
# --- Trung bình đơn giản toàn doanh nghiệp ---
# Fill Rate trung bình: 96.59%
# Tỷ lệ giao trễ trung bình: 28.81%

# %%
query = """
SELECT 
    c.city,
    o.product_id,
    p.product_name,
    p.category,
    CAST(SUM(o.actual_revenue) AS NUMERIC) as actual_revenue,
    CAST(SUM(o.expected_revenue) AS NUMERIC) as expected_revenue,
    ROUND(CAST(SUM(GREATEST(o.actual_revenue - o.expense, 0)) AS NUMERIC), 0) AS profit,
    ROUND(AVG(SAFE_DIVIDE(o.delivered_qty, o.order_qty)) * 100, 2) AS avg_fill_rate,
    ROUND(COUNTIF(o.actual_delivery_date > o.agreed_delivery_date) / COUNT(o.order_id) * 100, 2) AS avg_late_pct
FROM analytics.dim_customers c
JOIN analytics.fact_order_lines o ON c.customer_id = o.customer_id
JOIN analytics.dim_products p ON p.product_id = o.product_id
GROUP BY c.city, o.product_id, p.product_name, p.category
"""
perf_in_city_df_ = client.query(query).to_dataframe()
perf_in_city_df_
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1994: UserWarning:
#
# BigQuery Storage module not found, fetch data with the REST endpoint instead.
#          city product_id     product_name   category         actual_revenue  \
# 0   Ahmedabad   25891202    AM Butter 250      Dairy  20202468000.000000000
# 39  16297797000.000000000   2347423000.000000000          96.42         30.02
# 40  22821084000.000000000   2987802000.000000000          96.06         30.36
# 41   7232723000.000000000    941280000.000000000          96.25         29.13
# 42   6758850000.000000000   1304961000.000000000          96.48         28.35
# 43  52847442000.000000000   9510684000.000000000          96.24         29.16
# 44   2967470000.000000000    519584000.000000000          96.32         29.14
# 45   4305745000.000000000   1606308000.000000000          96.38         29.52
# 46  21541080000.000000000   4710885000.000000000          96.17         31.69
# 47  64416830000.000000000  15861493000.000000000          96.39         31.18
# 48   2305489000.000000000    782466000.000000000          96.14         30.76
# 49  37765482000.000000000   6704000000.000000000          96.50         30.16
# 50   6717480000.000000000   1236186000.000000000          96.39         30.49
# 51   3540152000.000000000    973520000.000000000          96.23         32.25
# 52  45522862000.000000000   9816876000.000000000          96.65         29.83
# 53  35778710000.000000000   4699980000.000000000          96.41         30.54

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np


# 1. Tạo bản sao để tránh ảnh hưởng df gốc
df_model_ = perf_in_city_df_.copy()

# 2. Ép kiểu 3 cột chính về float
cols_to_fix = ['profit', 'avg_fill_rate', 'avg_late_pct']
for col in cols_to_fix:
    df_model_[col] = pd.to_numeric(df_model_[col], errors='coerce')

# 3. Tạo biến giả (Dummies)
df_model_ = pd.get_dummies(df_model_, columns=['category', 'city'], drop_first=True)

# 4. CHỐT CHẶN CUỐI: Ép toàn bộ dataframe về float64 để loại bỏ kiểu 'object'
df_model_ = df_model_.select_dtypes(include=[np.number, 'bool']).astype(float)

# 5. Xác định X và y
# Lưu ý: Tên cột dummies có thể thay đổi tùy vào dữ liệu của bạn, 
# hãy kiểm tra df_model.columns để điền chính xác
X_cols = [col for col in df_model_.columns if col != 'lost_rev_pct']
X = df_model_[X_cols]
X = sm.add_constant(X)
y = df_model_['profit']

# 6. Chạy mô hình
model_ = sm.OLS(y, X).fit()

# 7. Xem kết quả
print(model_.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 profit   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.127e+30
# Date:                Thu, 02 Apr 2026   Prob (F-statistic):               0.00
# Time:                        19:49:47   Log-Likelihood:                 545.27
# No. Observations:                  54   AIC:                            -1075.
# Df Residuals:                      46   BIC:                            -1059.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -6.104e-05      0.001     -0.074      0.942      -0.002       0.002
# profit             1.0000   4.53e-16   2.21e+15      0.000       1.000       1.000
# avg_fill_rate   4.768e-07   8.58e-06      0.056      0.956   -1.68e-05    1.77e-05
# avg_late_pct    2.533e-07   1.34e-06      0.190      0.850   -2.43e-06    2.94e-06
# category_Dairy   2.98e-07   4.83e-06      0.062      0.951   -9.43e-06       1e-05
# category_Food  -2.384e-07   5.18e-06     -0.046      0.963   -1.07e-05    1.02e-05
# city_Surat       2.98e-07   6.18e-06      0.048      0.962   -1.21e-05    1.27e-05
# city_Vadodara  -1.431e-06    5.3e-06     -0.270      0.788   -1.21e-05    9.24e-06
# ==============================================================================
# Omnibus:                        6.388   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.294
# Skew:                           0.835   Prob(JB):                       0.0430
# Kurtosis:                       2.894   Cond. No.                     3.40e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.4e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
